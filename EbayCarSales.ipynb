# %% [markdown]
# # Analyzing the dataset of used Cars from eBay Kleinanzeigen

# %% [markdown]
# # 1.

# %%
import pandas as pd
import numpy as np

# %%
autos = pd.read_csv("autos.csv", encoding = "Windows-1252")

# %%
autos
# Out:
#                dateCrawled                                               name  \
# 0      2016-03-26 17:47:46                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1      2016-04-04 13:38:56         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2      2016-03-26 18:57:24                         Volkswagen_Golf_1.6_United
# 3      2016-03-12 16:58:10  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4      2016-04-01 14:38:50  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
# 5      2016-03-21 13:47:45  Chrysler_Grand_Voyager_2.8_CRD_Aut.Limited_Sto...
# 6      2016-03-20 17:55:21  VW_Golf_III_GT_Special_Electronic_Green_Metall...
# 7      2016-03-16 18:55:19                               Golf_IV_1.9_TDI_90PS
# 8      2016-03-22 16:51:34                                         Seat_Arosa
# 9      2016-03-16 13:47:02          Renault_Megane_Scenic_1.6e_RT_Klimaanlage
# 10     2016-03-15 01:41:36                       VW_Golf_Tuning_in_siber/grau
# ...

# %% [markdown]
# # 2.

# %%
autos.columns = ['date_crawled', 'name', 'seller', 'offer_type', 'price', 'abtest',
       'vehicle_type', 'registration_year', 'gearbox', 'power_PS', 'model',
       'odometer', 'registration_month', 'fuel_type', 'brand',
       'unrepaired_damage', 'ad_created', 'nr_of_pictures', 'postal_code',
       'last_seen']

# %%
all_vehicle_type = autos["vehicle_type"].value_counts()
print(all_vehicle_type)
# Out:
# limousine     12859
# kleinwagen    10822
# kombi          9127
# bus            4093
# cabrio         3061
# coupe          2537
# suv            1986
# andere          420
# Name: vehicle_type, dtype: int64

# %% [markdown]
# Limousine has the most seller

# %%
print(autos.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 20 columns):
# date_crawled          50000 non-null object
# name                  50000 non-null object
# seller                50000 non-null object
# offer_type            50000 non-null object
# price                 50000 non-null object
# abtest                50000 non-null object
# vehicle_type          44905 non-null object
# registration_year     50000 non-null int64
# gearbox               47320 non-null object
# power_PS              50000 non-null int64
# model                 47242 non-null object
# odometer              50000 non-null object
# registration_month    50000 non-null int64
# fuel_type             45518 non-null object
# brand                 50000 non-null object
# unrepaired_damage     40171 non-null object
# ad_created            50000 non-null object
# nr_of_pictures        50000 non-null int64
# postal_code           50000 non-null int64
# ...

# %%
autos.loc[autos["vehicle_type"].isnull(),:]
# Out:
#               date_crawled                                               name  \
# 8      2016-03-22 16:51:34                                         Seat_Arosa
# 10     2016-03-15 01:41:36                       VW_Golf_Tuning_in_siber/grau
# 11     2016-03-16 18:45:34                         Mercedes_A140_Motorschaden
# 27     2016-03-27 18:45:01             Hat_einer_Ahnung_mit_Ford_Galaxy_HILFE
# 46     2016-03-31 10:53:28                                       BMW_mit__Lpg
# 55     2016-03-07 02:47:54                     Mercedes_E320_AMG_zu_Tauschen!
# 59     2016-03-17 17:50:54               Mercedes_A_Klasse_W_168__A_140_gruen
# 64     2016-04-05 07:36:19                 Autotransport__Abschlepp_Schlepper
# 65     2016-04-04 19:30:39                      Ford_Fiesta_zum_ausschlachten
# 68     2016-04-03 17:36:59  Mini_cooper_s_clubman_/vollausstattung_/_Navi/...
# 71     2016-03-28 19:39:35  Suche_Opel_Astra_F__Corsa_oder_Kadett_E_mit_Re...
# ...

# %%
autos.head()
# Out:
#           date_crawled                                               name  \
# 0  2016-03-26 17:47:46                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1  2016-04-04 13:38:56         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2  2016-03-26 18:57:24                         Volkswagen_Golf_1.6_United
# 3  2016-03-12 16:58:10  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4  2016-04-01 14:38:50  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
#
#    seller offer_type   price   abtest vehicle_type  registration_year  \
# 0  privat    Angebot  $5,000  control          bus               2004
# 1  privat    Angebot  $8,500  control    limousine               1997
# 2  privat    Angebot  $8,990     test    limousine               2009
# 3  privat    Angebot  $4,350  control   kleinwagen               2007
# 4  privat    Angebot  $1,350     test        kombi               2003
#
#      gearbox  power_PS   model   odometer  registration_month fuel_type  \
# ...

# %%
autos.columns
# Out:
# Index(['date_crawled', 'name', 'seller', 'offer_type', 'price', 'abtest',
#        'vehicle_type', 'registration_year', 'gearbox', 'power_PS', 'model',
#        'odometer', 'registration_month', 'fuel_type', 'brand',
#        'unrepaired_damage', 'ad_created', 'nr_of_pictures', 'postal_code',
#        'last_seen'],
#       dtype='object')

# %% [markdown]
# Change from camel case to snake case since python use snake case

# %% [markdown]
# # 3.

# %%
autos.describe(include = "all")
# Out:
#                date_crawled         name  seller offer_type  price abtest  \
# count                 50000        50000   50000      50000  50000  50000
# unique                48213        38754       2          2   2357      2
# top     2016-04-02 11:37:04  Ford_Fiesta  privat    Angebot     $0   test
# freq                      3           78   49999      49999   1421  25756
# mean                    NaN          NaN     NaN        NaN    NaN    NaN
# std                     NaN          NaN     NaN        NaN    NaN    NaN
# min                     NaN          NaN     NaN        NaN    NaN    NaN
# 25%                     NaN          NaN     NaN        NaN    NaN    NaN
# 50%                     NaN          NaN     NaN        NaN    NaN    NaN
# 75%                     NaN          NaN     NaN        NaN    NaN    NaN
# max                     NaN          NaN     NaN        NaN    NaN    NaN
#
#        vehicle_type  registration_year  gearbox      power_PS  model  \
# ...

# %% [markdown]
# CANDIDATES FOR DROPPING

# %%
autos["seller"].value_counts()
# Out:
# privat        49999
# gewerblich        1
# Name: seller, dtype: int64

# %%
autos["offer_type"].value_counts()
# Out:
# Angebot    49999
# Gesuch         1
# Name: offer_type, dtype: int64

# %%
autos["nr_of_pictures"].value_counts()
# Out:
# 0    50000
# Name: nr_of_pictures, dtype: int64

# %% [markdown]
# END

# %% [markdown]
# Converting price and odometer to int dtype
# Changing the column name with the unit of price and odometer

# %%
autos["price"] = (autos["price"]
                  .str.replace("$","")
                  .str.replace(",","")
                  .astype(int))

# %%
print(autos["price"].head())
# Out:
# 0    5000
# 1    8500
# 2    8990
# 3    4350
# 4    1350
# Name: price, dtype: int64

# %%
autos["odometer"] = (autos["odometer"]
                  .str.replace("km","")
                  .str.replace(",","")
                  .astype(int))

# %%
#This are string values, need to convert to int
price_odometer = autos[["price","odometer"]]
print(price_odometer.head())
# Out:
#    price  odometer
# 0   5000    150000
# 1   8500    150000
# 2   8990     70000
# 3   4350     70000
# 4   1350    150000

# %%
autos.columns = ['date_crawled', 'name', 'seller', 'offer_type', 'price_$', 'abtest',
       'vehicle_type', 'registration_year', 'gearbox', 'power_PS', 'model',
       'odometer_km', 'registration_month', 'fuel_type', 'brand',
       'unrepaired_damage', 'ad_created', 'nr_of_pictures', 'postal_code',
       'last_seen']

# %% [markdown]
# # 4.
# Finding ang outlier

# %%
print(autos["price_$"].unique().shape)
print(autos["price_$"].describe())
# Out:
# (2357,)
# count    5.000000e+04
# mean     9.840044e+03
# std      4.811044e+05
# min      0.000000e+00
# 25%      1.100000e+03
# 50%      2.950000e+03
# 75%      7.200000e+03
# max      1.000000e+08
# Name: price_$, dtype: float64

# %% [markdown]
# Might be an outlier since the price is too large and i cant find the model of the car

# %%
autos[(autos["price_$"] == autos["price_$"].max())]
# Out:
#               date_crawled                         name  seller offer_type  \
# 39705  2016-03-22 14:58:27  Tausch_gegen_gleichwertiges  privat    Angebot
#
#         price_$   abtest vehicle_type  registration_year    gearbox  power_PS  \
# 39705  99999999  control    limousine               1999  automatik       224
#
#           model  odometer_km  registration_month fuel_type          brand  \
# 39705  s_klasse       150000                   9    benzin  mercedes_benz
#
#       unrepaired_damage           ad_created  nr_of_pictures  postal_code  \
# 39705               NaN  2016-03-22 00:00:00               0        73525
#
#                  last_seen
# 39705  2016-04-06 05:15:30

# %% [markdown]
# There are a lot of cars with no price

# %%
autos[(autos["price_$"] == 0)]
# Out:
#               date_crawled                                               name  \
# 27     2016-03-27 18:45:01             Hat_einer_Ahnung_mit_Ford_Galaxy_HILFE
# 71     2016-03-28 19:39:35  Suche_Opel_Astra_F__Corsa_oder_Kadett_E_mit_Re...
# 80     2016-03-09 15:57:57  Nissan_Primera_Hatchback_1_6_16v_73_Kw___99Ps_...
# 87     2016-03-29 23:37:22                      Bmw_520_e39_zum_ausschlachten
# 99     2016-04-05 09:48:54                    Peugeot_207_CC___Cabrio_Bj_2011
# 118    2016-03-12 05:03:00  VW_Sharan_V6_204_PS_Karosse_Rohkarosse_mit_Pap...
# 146    2016-03-22 23:59:28                                    Ford_Fiesta_rot
# 167    2016-04-02 19:43:45  Suche_VW_Multivan_Innenausstattung_Set_oder_TE...
# 180    2016-03-19 10:50:25                                       Zu_verkaufen
# 226    2016-03-25 23:52:12                      Porsche_911_S_Targa__67er_SWB
# 234    2016-03-05 16:56:22                                   Fiat_Punto_Sport
# ...

# %%
autos["price_$"]
# Out:
# 0         5000
# 1         8500
# 2         8990
# 3         4350
# 4         1350
# 5         7900
# 6          300
# 7         1990
# 8          250
# 9          590
# 10         999
# 11         350
# 12        5299
# 13        1350
# 14        3999
# 15       18900
# 16         350
# 17        5500
# 18         300
# 19        4150
# 20        3500
# 21       41500
# 22       25450
# 23        7999
# 24       48500
# 25          90
# 26         777
# 27           0
# 28        5250
# 29        4999
#          ...
# 49970    15800
# 49971      950
# 49972     3300
# 49973     6000
# 49974        0
# 49975     9700
# 49976     5900
# 49977     5500
# 49978      900
# 49979    11000
# 49980      400
# 49981     2000
# 49982     1950
# 49983      600
# 49984        0
# 49985     1000
# 49986    15900
# 49987    21990
# 49988     9550
# 49989      150
# 49990    17500
# 49991      500
# 49992     4800
# 49993     1650
# 49994     5000
# 49995    24900
# 49996     1980
# ...

# %%
autos["price_$"].value_counts().sort_index().head(20)
# Out:
# 0     1421
# 1      156
# 2        3
# 3        1
# 5        2
# 8        1
# 9        1
# 10       7
# 11       2
# 12       3
# 13       2
# 14       1
# 15       2
# 17       3
# 18       1
# 20       4
# 25       5
# 29       1
# 30       7
# 35       1
# Name: price_$, dtype: int64

# %%
autos["price_$"].value_counts().sort_index().tail(20)
# Out:
# 197000      1
# 198000      1
# 220000      1
# 250000      1
# 259000      1
# 265000      1
# 295000      1
# 299000      1
# 345000      1
# 350000      1
# 999990      1
# 999999      2
# 1234566     1
# 1300000     1
# 3890000     1
# 10000000    1
# 11111111    2
# 12345678    3
# 27322222    1
# 99999999    1
# Name: price_$, dtype: int64

# %%
autos["price_$"] = autos.loc[autos["price_$"].between(1,350000),"price_$"]

# %%
autos["price_$"].describe(include = "all")
# Out:
# count     48565.000000
# mean       5888.935591
# std        9059.854754
# min           1.000000
# 25%        1200.000000
# 50%        3000.000000
# 75%        7490.000000
# max      350000.000000
# Name: price_$, dtype: float64

# %% [markdown]
# REMOVED THE OUTLIER WITH THE VALUE 99999999 AND 0 PRICE.
# ITS SEEMS THAT 99999999 TO BE AN OUTLIER SINCE ITS ON EBAY. AS FOR THE ZERO PRICE. ITS AN ERROR

# %%
print(autos["odometer_km"].unique().shape)
print(autos["odometer_km"].describe())
# Out:
# (13,)
# count     50000.000000
# mean     125732.700000
# std       40042.211706
# min        5000.000000
# 25%      125000.000000
# 50%      150000.000000
# 75%      150000.000000
# max      150000.000000
# Name: odometer_km, dtype: float64

# %%
print(autos[(autos["odometer_km"] == autos["odometer_km"].max() )].shape)
# Out:
# (32424, 20)

# %% [markdown]
# There are no outliers in the odometer column since the max value is equal to the median and the 75 percentile.

# %% [markdown]
# # 5.

# %%
autos["date_crawled"].value_counts(normalize = True,dropna=False)
# Out:
# 2016-04-02 11:37:04    0.00006
# 2016-03-10 15:36:24    0.00006
# 2016-04-04 16:40:33    0.00006
# 2016-03-25 19:57:10    0.00006
# 2016-04-02 15:49:30    0.00006
# 2016-03-30 17:37:35    0.00006
# 2016-03-19 17:36:18    0.00006
# 2016-03-29 23:42:13    0.00006
# 2016-03-09 11:54:38    0.00006
# 2016-03-05 16:57:05    0.00006
# 2016-03-08 10:40:35    0.00006
# 2016-03-12 16:06:22    0.00006
# 2016-03-21 20:37:19    0.00006
# 2016-03-11 22:38:16    0.00006
# 2016-03-30 19:48:02    0.00006
# 2016-03-22 09:51:06    0.00006
# 2016-03-21 16:37:21    0.00006
# 2016-03-14 20:50:02    0.00006
# 2016-03-23 18:39:34    0.00006
# 2016-03-27 22:55:05    0.00006
# 2016-03-16 21:50:53    0.00006
# 2016-03-23 19:38:20    0.00006
# 2016-03-11 17:47:44    0.00004
# 2016-03-11 11:54:09    0.00004
# 2016-03-20 14:54:13    0.00004
# 2016-03-08 13:51:58    0.00004
# 2016-04-04 18:46:47    0.00004
# 2016-04-03 16:48:45    0.00004
# 2016-03-28 16:45:41    0.00004
# 2016-03-31 12:55:26    0.00004
# ...

# %%
autos["date_crawled"].describe()
# Out:
# count                   50000
# unique                  48213
# top       2016-04-02 11:37:04
# freq                        3
# Name: date_crawled, dtype: object

# %%
#autos_copy["date_crawled"]= autos_copy["date_crawled"].str.split("-")

# %%
autos["date_crawled"]= (autos["date_crawled"]
                       .str.split()
                     .str[0]
                    )

# %%
autos["date_crawled"].value_counts(dropna = False).sort_index()
# Out:
# 2016-03-05    1269
# 2016-03-06     697
# 2016-03-07    1798
# 2016-03-08    1665
# 2016-03-09    1661
# 2016-03-10    1606
# 2016-03-11    1624
# 2016-03-12    1839
# 2016-03-13     778
# 2016-03-14    1831
# 2016-03-15    1699
# 2016-03-16    1475
# 2016-03-17    1576
# 2016-03-18     653
# 2016-03-19    1745
# 2016-03-20    1891
# 2016-03-21    1876
# 2016-03-22    1647
# 2016-03-23    1619
# 2016-03-24    1455
# 2016-03-25    1587
# 2016-03-26    1624
# 2016-03-27    1552
# 2016-03-28    1742
# 2016-03-29    1709
# 2016-03-30    1681
# 2016-03-31    1596
# 2016-04-01    1690
# 2016-04-02    1770
# 2016-04-03    1934
# 2016-04-04    1826
# 2016-04-05     655
# 2016-04-06     159
# 2016-04-07      71
# Name: date_crawled, dtype: int64

# %%
autos["date_crawled"].value_counts()
# Out:
# 2016-04-03    1934
# 2016-03-20    1891
# 2016-03-21    1876
# 2016-03-12    1839
# 2016-03-14    1831
# 2016-04-04    1826
# 2016-03-07    1798
# 2016-04-02    1770
# 2016-03-19    1745
# 2016-03-28    1742
# 2016-03-29    1709
# 2016-03-15    1699
# 2016-04-01    1690
# 2016-03-30    1681
# 2016-03-08    1665
# 2016-03-09    1661
# 2016-03-22    1647
# 2016-03-26    1624
# 2016-03-11    1624
# 2016-03-23    1619
# 2016-03-10    1606
# 2016-03-31    1596
# 2016-03-25    1587
# 2016-03-17    1576
# 2016-03-27    1552
# 2016-03-16    1475
# 2016-03-24    1455
# 2016-03-05    1269
# 2016-03-13     778
# 2016-03-06     697
# 2016-04-05     655
# 2016-03-18     653
# 2016-04-06     159
# 2016-04-07      71
# Name: date_crawled, dtype: int64

# %% [markdown]
# 1. 2016-04-03 has the most date_crawled = 1934.
# 2. 2016-04-07 has the least date_crawled = 71
# 3. There are no values == 1.
# 4. We use Series.sort_index() method because Series.value_counts() returns a series of values of each date and date as its index.
# 5. We used normalize to scale the column to 0-1 only
# 6. The first to crawl is in 2016-03-05 which has a value of 1269
# 7. The last to crawl is in 2016-04-07 which has a value of 71. Also the least date_crawled.

# %%
autos["ad_created"]= (autos["ad_created"]
                       .str.split()
                     .str[0]
                    )

# %%
autos["ad_created"].value_counts(dropna = False).sort_index()
# Out:
# 2015-06-11       1
# 2015-08-10       1
# 2015-09-09       1
# 2015-11-10       1
# 2015-12-05       1
# %%
autos["registration_year"].describe()
# Out:
# count    50000.000000
# mean      2005.073280
# std        105.712813
# min       1000.000000
# 25%       1999.000000
# 50%       2003.000000
# 75%       2008.000000
# max       9999.000000
# Name: registration_year, dtype: float64

# %% [markdown]
# The max and min value is an outlier

# %%
autos["registration_year"] = autos.loc[(autos["registration_year"]
                                                  .between(autos["registration_year"].min()+900,autos["registration_year"].max()-7899)),"registration_year"]

# %% [markdown]
# # 6.

# %%
autos["registration_year"].describe()
# Out:
# count    49976.000000
# mean      2003.366836
# std          7.693943
# min       1910.000000
# 25%       1999.000000
# 50%       2003.000000
# 75%       2008.000000
# max       2019.000000
# Name: registration_year, dtype: float64

# %% [markdown]
# I cleaned it by selecting only values between min(which is 1000) + 900 and max(which is 9999) - 7899
#     #between 1900 and 2100

# %%
autos["registration_year"].value_counts(normalize = True)
# Out:
# 2000.0    0.067112
# 2005.0    0.060329
# 1999.0    0.060029
# 2004.0    0.054766
# 2003.0    0.054566
# 2006.0    0.054186
# 2001.0    0.054086
# 2002.0    0.050684
# 1998.0    0.049084
# 2007.0    0.046102
# 2008.0    0.044641
# 2009.0    0.041980
# 1997.0    0.040579
# 2011.0    0.032696
# 2010.0    0.031955
# 2017.0    0.029074
# 1996.0    0.028894
# 2012.0    0.026473
# 2016.0    0.026333
# 1995.0    0.026273
# 2013.0    0.016128
# 2014.0    0.013326
# 1994.0    0.013206
# 2018.0    0.009845
# 1993.0    0.008904
# 2015.0    0.007984
# 1990.0    0.007904
# 1992.0    0.007824
# 1991.0    0.007123
# 1989.0    0.003622
#             ...
# 1966.0    0.000440
# 1975.0    0.000380
# 1969.0    0.000380
# 1965.0    0.000340
# 1964.0    0.000240
# 1963.0    0.000180
# 1910.0    0.000180
# 1959.0    0.000140
# 1961.0    0.000120
# 1956.0    0.000100
# 1962.0    0.000080
# 1958.0    0.000080
# 1937.0    0.000080
# 2019.0    0.000060
# 1950.0    0.000060
# 1934.0    0.000040
# ...

# %%
autos["brand"].value_counts()
# Out:
# volkswagen        10687
# opel               5461
# bmw                5429
# mercedes_benz      4734
# audi               4283
# ford               3479
# renault            2404
# peugeot            1456
# fiat               1308
# seat                941
# skoda               786
# mazda               757
# nissan              754
# smart               701
# citroen             701
# toyota              617
# sonstige_autos      546
# hyundai             488
# volvo               457
# mini                424
# mitsubishi          406
# honda               399
# kia                 356
# alfa_romeo          329
# porsche             294
# suzuki              293
# chevrolet           283
# chrysler            181
# dacia               129
# daihatsu            128
# jeep                110
# subaru              109
# land_rover           99
# saab                 80
# daewoo               79
# trabant              78
# jaguar               77
# rover                69
# ...

# %% [markdown]
# # 7.

# %% [markdown]
# ## Exploring the brand column

# %% [markdown]
# Choosing what brand to aggregate. Because we're computing the mean. And if data is not large enough. Then it wont be reliable

# %%
brands = autos["brand"].value_counts(normalize = True)

# %%
all_brand = {}
common_brands = brands[brands > 5].index

# %%
autos["brand"].value_counts(normalize = True).head()
# Out:
# volkswagen       0.21374
# opel             0.10922
# bmw              0.10858
# mercedes_benz    0.09468
# audi             0.08566
# Name: brand, dtype: float64

# %%
for brand in all_brand_unique:
    brand_mean = autos.loc[(autos["brand"] == brand),"price_$"].mean()
    all_brand[brand] = int(brand_mean)

# %%
all_brand
# Out:
# {'audi': 9212,
#  'bmw': 8261,
#  'ford': 3728,
#  'mercedes_benz': 8536,
#  'opel': 2944,
#  'volkswagen': 5332}

# %%
all_brand_mean = pd.Series(all_brand)
print(all_brand_mean)
# Out:
# audi             9212
# bmw              8261
# ford             3728
# mercedes_benz    8536
# opel             2944
# volkswagen       5332
# dtype: int64

# %%
df = pd.DataFrame(all_brand_mean, columns = ["mean_price"])
print()
