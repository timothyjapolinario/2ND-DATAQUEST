# %% [markdown]
# # Guided Project: Visualizing (Mostly on distributions)Earning Based On College Majors
# ### Timothy Jay T. Apolinario, 12/02/2020
#
# The goal of the project is only to make plots. It only contains minor cleaning and exploring the dataset.

# %%
import pandas as pd
import pandas.plotting
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# The dataset contains information on each College Majors. Below contains the name<br>
# of the college majors and its attributes.
#
# <b>Rank</b> - Rank by median earnings (the dataset is ordered by this column).<br>
# <b>Major_code</b> - Major code.<br>
# <b>Major</b> - Major description.<br>
# <b>Total</b> - Total number of people with major.<br>
# <b>Men</b> - Male graduates.<br>
# <b>Women</b> - Female graduates.<br>
# <b>Major_category</b> - Category of major.<br>
# <b>ShareWomen</b> - Women as share of total.(Total/Women)<br>
# <b>Sample_size</b> - Sample size (unweighted) of full-time.<br>
# <b>Employed</b> - Number employed.<br>
# <b>Full_time</b> - Number employed 35 hours or more.<br>
# <b>Part_time</b> - Number employed less than 35 hours.<br>
# <b>Median</b> - Median salary of full-time, year-round workers.<br>
# <b>Low_wage_jobs</b> - Number in low-wage service jobs.<br>

# %% [markdown]
# # 1. Reading the Data and Dropping NA Values

# %%
recent_grads = pd.read_csv('D:\\Guided Projects\\Guided Project Visualizing Earning Based On College Majors\\recent-grads.csv')
#recent_grads.iloc[0]
#recent_grads.head()
#recent_grads.tail()
raw = recent_grads.describe()
recent_grads = recent_grads.dropna()

# %%
recent_grads.head()
# Out:
#    Rank  Major_code                                      Major    Total  \
# 0     1        2419                      PETROLEUM ENGINEERING   2339.0
# 1     2        2416             MINING AND MINERAL ENGINEERING    756.0
# 2     3        2415                  METALLURGICAL ENGINEERING    856.0
# 3     4        2417  NAVAL ARCHITECTURE AND MARINE ENGINEERING   1258.0
# 4     5        2405                       CHEMICAL ENGINEERING  32260.0
#
#        Men    Women Major_category  ShareWomen  Sample_size  Employed  ...  \
# 0   2057.0    282.0    Engineering    0.120564           36      1976  ...
# 1    679.0     77.0    Engineering    0.101852            7       640  ...
# 2    725.0    131.0    Engineering    0.153037            3       648  ...
# 3   1123.0    135.0    Engineering    0.107313           16       758  ...
# 4  21239.0  11021.0    Engineering    0.341631          289     25694  ...
#
#    Part_time  Full_time_year_round  Unemployed  Unemployment_rate  Median  \
# ...

# %%
high_medians = recent_grads.sort_values("Median")
high_medians.tail().plot.barh(x = "Major", y = "Median")
# Out:
# <AxesSubplot:ylabel='Major'>

# %% [markdown]
# # 2. Using Scatterplot to see if there is a relationship for some selected columns

# %% [markdown]
# ## Sample Size vs Median

# %%
plt.scatter(recent_grads["Sample_size"], recent_grads["Median"])
plt.xlabel("Sample Size")
plt.ylabel("Median",rotation = 90)
plt.title("Sample Size vs Median")
plt.show()

# %% [markdown]
# Zooming to 1000 Sample Size

# %%
plt.scatter(recent_grads["Sample_size"], recent_grads["Median"])
plt.xlim(0,1000)
plt.xlabel("Sample Size")
plt.ylabel("Median",rotation = 90)
plt.title("Sample Size vs Median")
plt.show()

# %% [markdown]
# The dataset contains sample size for each major.<br> We can see that most of the samplesize contains less than 1000. There is an extreme value or outlier for sample size and median. We can see that one sample size is over 4000. There is also a median that is over 100,000.
#
# There is no relationship between Sample Size and Median

# %% [markdown]
# ## Sample Size vs Unemployment Rate

# %% [markdown]
# There are a lot of small sample size. Should I remove it?

# %%
plt.scatter(recent_grads["Sample_size"], recent_grads["Unemployment_rate"])
plt.xlabel("Sample Size")
plt.ylabel("Unemployment Rate",rotation = 90)
plt.title("Sample Size vs Unemployment Rate")
plt.show()

# %%
plt.scatter(recent_grads["Sample_size"], recent_grads["Unemployment_rate"])
plt.xlim(0,1000)
plt.xlabel("Sample Size")
plt.ylabel("Unemployment Rate",rotation = 90)
plt.title("Sample Size vs Unemployment Rate")
plt.show()

# %% [markdown]
# Same as with the first plot, one sample size is greater than 4000.
# There is no relationship between Sample Size and Unemployment rate

# %% [markdown]
# ## Full Time vs Median

# %%
plt.scatter(recent_grads["Full_time"],recent_grads["Median"])
plt.xlabel("Full Time")
plt.ylabel("Median",rotation = 90)
plt.title("Full Time vs Median")
plt.show()

# %% [markdown]
# We can see from the plot, for each major courses, as the number of full time increases, the median gets lower.

# %% [markdown]
# ## Percentage of women vs Unemployment Rate

# %%
plt.scatter(recent_grads["ShareWomen"],recent_grads["Unemployment_rate"])
plt.xlabel("Percentage of Women")
plt.ylabel("Unemployment Rate", rotation = 90)
plt.title("Share Women vs Unemployment Rate")
# Out:
# Text(0.5, 1.0, 'Share Women vs Unemployment Rate')

# %% [markdown]
# ## Men vs Median

# %%
plt.scatter(recent_grads["Men"],recent_grads["Median"])
plt.xlabel("Number of Men")
plt.ylabel("Median")
plt.title("Men vs Median")
plt.show()

# %% [markdown]
# ## Women vs Median

# %%
plt.scatter(recent_grads["Women"],recent_grads["Median"])
plt.xlabel("Number of Women")
plt.ylabel("Median", rotation = 90)
plt.title("Women vs Median")
plt.show()

# %% [markdown]
# ### Values of number for Number for both genders, between 0 - 100,000, Men has higher median than women

# %%
recent_grads.head()
# Out:
#    Rank  Major_code                                      Major    Total  \
# 0     1        2419                      PETROLEUM ENGINEERING   2339.0
# 1     2        2416             MINING AND MINERAL ENGINEERING    756.0
# 2     3        2415                  METALLURGICAL ENGINEERING    856.0
# 3     4        2417  NAVAL ARCHITECTURE AND MARINE ENGINEERING   1258.0
# 4     5        2405                       CHEMICAL ENGINEERING  32260.0
#
#        Men    Women Major_category  ShareWomen  Sample_size  Employed  ...  \
# 0   2057.0    282.0    Engineering    0.120564           36      1976  ...
# 1    679.0     77.0    Engineering    0.101852            7       640  ...
# 2    725.0    131.0    Engineering    0.153037            3       648  ...
# 3   1123.0    135.0    Engineering    0.107313           16       758  ...
# 4  21239.0  11021.0    Engineering    0.341631          289     25694  ...
#
#    Part_time  Full_time_year_round  Unemployed  Unemployment_rate  Median  \
# ...

# %% [markdown]
# ## Sorting majors by Popularity
# I based the popularity of each major category by the number or count of graduates

# %%
majors = recent_grads["Major_category"].value_counts()
majors.describe()
# Out:
# count    16.000000
# mean     10.750000
# std       6.329824
# min       1.000000
# 25%       7.750000
# 50%       9.500000
# 75%      13.250000
# max      29.000000
# Name: Major_category, dtype: float64

# %%
#Based from the mean
popular_majors = majors[majors > 10].index
unpopular_majors = majors[majors<10].index

popular_major_df = recent_grads[recent_grads["Major_category"].isin(popular_majors)]
popular_major_median = popular_major_df["Median"]
popular_major_median.head()

plt.pie(majors.head())
plt.legend(labels = list(popular_major_df["Major"].head()),bbox_to_anchor = [1,0.5])

# %%
unpopular_major_df = recent_grads[recent_grads["Major_category"].isin(unpopular_majors)]
unpopular_major_median = unpopular_major_df["Median"]
unpopular_major_median.head()

plt.pie(majors.tail())
plt.legend(labels = list(unpopular_major_df["Major"].head()),bbox_to_anchor = [1,0.5])

# %%
recent_grads.sort_values("Unemployment_rate").tail(10).plot.barh(x = 'Major',y = 'Unemployment_rate', legend = False)
recent_grads.sort_values("Unemployment_rate").head(10).plot.barh(x = 'Major', y= 'Unemployment_rate', legend= False)
# Out:
# <AxesSubplot:ylabel='Major'>

# %%
recent_grads.sort_values("ShareWomen").tail(10).plot.barh(x = 'Major',y = 'ShareWomen', legend = False)
plt.title("Major with most women")

recent_grads.sort_values("ShareWomen", ascending = False).tail(10).plot.barh(x = 'Major', y= 'ShareWomen', legend= False)
plt.title("Major with least women")
# Out:
# Text(0.5, 1.0, 'Major with least women')

# %%
fig,ax = plt.subplots()
ax.hist(unpopular_major_median)
# Out:
# (array([ 3.,  4., 13., 14.,  6.,  7.,  0.,  1.,  3.,  1.]),
#  array([23400., 26460., 29520., 32580., 35640., 38700., 41760., 44820.,
#         47880., 50940., 54000.]),
#  <a list of 10 Patch objects>)

# %%
fig = plt.figure(figsize=(15,5))
ax1 = fig.add_subplot(1,2,1)
ax1.hist(popular_major_median,bins=30,range=(0,100000))
ax1.set_xlabel("Median")
ax1.set_ylabel("Count")
ax1.set_title("Distribution of Median for Popular Majors")
ax2 = fig.add_subplot(1,2,2)
ax2.hist(unpopular_major_median,bins=30,range=(0,100000))
ax2.set_xlabel("Median")
ax2.set_ylabel("count")
ax2.set_title("Distibution of Median for Unpopular Majors")
# Out:
# Text(0.5, 1.0, 'Distibution of Median for Unpopular Majors')

# %% [markdown]
# Do students in more popular major make more money?
#     1. As the graph shows, the popular major makes more than 60 000.
#     2. The highest median for unpopular major does not exceed in 60 000.
#     3. Though, the most count of popular major and unpopular major is in between 20000 - 40000, popular major has still
#         greater numbers in terms of greater median since the population of unpopular major is less.

# %%
median_male_majority = recent_grads[recent_grads["Women"] < recent_grads["Men"]]["Median"]
median_female_majority = recent_grads[recent_grads["Women"] > recent_grads["Men"]]["Median"]

# %%
fig = plt.figure(figsize = (15,5))
ax1 = fig.add_subplot(1,2,1)
ax1.hist(median_male_majority,bins=30,range=(0,100000))
ax1.set_xlabel("Median")
ax1.set_ylabel("Frequency")
ax1.set_title("Distribution of Median Salary, Number of Women < Men Major")
ax2 = fig.add_subplot(1,2,2)
ax2.hist(median_female_majority,bins=30,range=(0,100000))
ax2.set_xlabel("Median")
ax2.set_ylabel("Frequency")
ax2.set_title("Distribution of Median Salary, Number of Women > Men Major")
# Out:
# Text(0.5, 1.0, 'Distribution of Median Salary, Number of Women > Men Major')

# %% [markdown]
# Question : Do students that majored in subjects that were majority female make more money?
# I disregard the frequency since the total number of men in the data is lesser than the total number of women
# 1. The highest median where number of men is greater is greater than 70,000 so by means, Men makes the highest median
# 2. Disregard the frequency, the high medians where number of men is greater are scattered between 30,000 to 50,000
# 3. Disregard the frequency, the high medians where number of women is greater are compressed in 30,000 more or less.

# %%
fig,ax = plt.subplots()
ax.scatter(recent_grads["Full_time"],recent_grads["Median"])
ax.set_title("Number of Full Time in each Major vs the Salary Median")
ax.set_xlabel("Number of Full Time")
ax.set_ylabel("Median Salary")
# Out:
# Text(0, 0.5, 'Median Salary')

# %% [markdown]
# Question : Is there any link between the number of full-time employees and median salary?
# 1. There is a small correlation between the Number of Full Timt and the Median Salary.
# 2. As the number of Full time increases, the median salary decreases.
# 3. But, most of the number of full time is in between 0 to 50,000 and their median salary ranges from 20,000 to 75,000

# %% [markdown]
# # 3. Understanding the Distribution

# %%
fig,ax = plt.subplots()
ax.hist(recent_grads["Sample_size"], 20)
ax.set_title("Sample Size Distribution")

fig,ax = plt.subplots()
ax.hist(recent_grads["Median"])
ax.set_title("Median Distribution")

fig,ax = plt.subplots()
ax.hist(recent_grads["Employed"])
ax.set_title("Employed Distribution")

fig,ax = plt.subplots()
ax.hist(recent_grads["Full_time"])
ax.set_title("Full Time Distribution")

fig,ax = plt.subplots()
ax.hist(recent_grads["Men"],20)
ax.set_title("Number of men per major Distribution")

fig,ax = plt.subplots()
ax.hist(recent_grads["Women"],20)
ax.set_title("Number of women per major Distribution")
# Out:
# Text(0.5, 1.0, 'Number of women per major Distribution')

# %%
fig,ax = plt.subplots()
ax.hist(recent_grads["ShareWomen"])
ax.set_title("Share Women Distribution")

fig,ax = plt.subplots()
ax.hist(recent_grads["Unemployment_rate"])
ax.set_title("Unemployment Rate Distribution")
# Out:
# Text(0.5, 1.0, 'Unemployment Rate Distribution')

# %%
recent_grads["Women"].sum()
# Out:
# 3895228.0

# %%
recent_grads["Men"].sum()
# Out:
# 2876426.0

# %%
fig,ax = plt.subplots()
num_men_dominant = recent_grads[recent_grads["Women"]<recent_grads["Men"]]["Major"].describe()['count']
num_women_dominant = recent_grads[recent_grads["Women"]>recent_grads["Men"]]["Major"].describe()['count']
gender_dominant =  [num_men_dominant,num_women_dominant]
genders = ["Men", "Women"]
ax.pie(gender_dominant, labels = genders,autopct='%1.2f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x17edcc09cc8>,
# ...
#  [Text(0.19980052901159365, 1.0817022458175296, 'Men'),
#   Text(-0.1998004277353191, -1.0817022645242007, 'Women')],
#  [Text(0.10898210673359653, 0.5900194068095616, '44.19%'),
#   Text(-0.10898205149199224, -0.5900194170132003, '55.81%')])

# %% [markdown]
# Question: What percent of majors are predominantly male? Predominantly female?
#
#     1. Judging by the pie chart, around 55.81% of the majors are pre dominantly by women and 44.19% percent of the Majors
#     are dominated by men
#
# Question: What's the most common median salary range?
#     1. Based on the histogram, the common median salary is between $30,000 to $40,000

# %% [markdown]
# # 4. Using the Scatter Matrix for Summarization

# %%
pd.plotting.scatter_matrix(recent_grads[["Sample_size", "Median"]], figsize = (20,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000017EDA0B7B48>,
# ...
#       dtype=object)

# %%
pd.plotting.scatter_matrix(recent_grads[["Sample_size", "Median","Unemployment_rate"]], figsize = (20,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000017EDA76DF48>,
# ...
#       dtype=object)

# %%
# Out:
# Text(0.5, 1.0, 'Major with most women')

# %%
# Out:
# Text(0.5, 1.0, 'Major with least women')

# %%
# Out:
# Text(0.5, 1.0, 'Major with least men')

# %% [markdown]
# ## Some ideas to continue
# - Use a grouped bar plot to compare the number of men with the number of women in each category of majors.
# - Use a box plot to explore the distributions of median salaries and unemployment rate.
# - Use a hexagonal bin plot to visualize the columns that had dense scatter plots from earlier in the project.
